# %% [markdown]
# # Functions
#
# Functions is nothing more than a block of code that can `execute an action or task`. Functions are used to perform a specific task and can be called by their name, usually, functions are used to `make code reusable and to make it easier` to read and maintain.

# %%
def my_function():
    print("Hello World")

my_function()
# Out:
# Hello World

# %%
def sum(a, b):
    return a + b

print(sum(1, 2))
# Out:
# 3

# %% [markdown]
# ## example of function

# %%
def send_email(name, email):
    email='test@gamil.com'
    senha='123456'
    name_recipient=name
    email_recipient=email
    #connect to email server
    #email corpora
    #send email
    #disconnect from email server

# %%
clients = {
    'John': 'john@example.com',
    'Jane': 'jane@example.com',
    'Bob': 'bob@example.com',
    'Alice': 'alice@example.com',
}

for client, email in clients.items():
    send_email(client, email)
    print(f"Email sent to {client} at {email}")
# Out:
# Email sent to John at john@example.com
# Email sent to Jane at jane@example.com
# Email sent to Bob at bob@example.com
# Email sent to Alice at alice@example.com

# %%
clients.items()
# Out:
# dict_items([('John', 'john@example.com'), ('Jane', 'jane@example.com'), ('Bob', 'bob@example.com'), ('Alice', 'alice@example.com')])

# %%
clients.keys()
# Out:
# dict_keys(['John', 'Jane', 'Bob', 'Alice'])

# %%
clients.values()
# Out:
# dict_values(['john@example.com', 'jane@example.com', 'bob@example.com', 'alice@example.com'])
